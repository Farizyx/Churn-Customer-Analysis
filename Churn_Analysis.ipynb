# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\salma\Downloads\Customer Churn.csv")

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df['TotalCharges']=df['TotalCharges'].replace(' ','0')
df['TotalCharges']=df['TotalCharges'].astype('float')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7043.000000  7043.000000     7043.000000   7043.000000
# mean        0.162147    32.371149       64.761692   2279.734304
# std         0.368612    24.559481       30.090047   2266.794470
# min         0.000000     0.000000       18.250000      0.000000
# 25%         0.000000     9.000000       35.500000    398.550000
# 50%         0.000000    29.000000       70.350000   1394.550000
# 75%         0.000000    55.000000       89.850000   3786.600000
# max         1.000000    72.000000      118.750000   8684.800000

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['customerID'].duplicated().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
def conv(value):
    if value == 1:
        return'yes'
    else:
        return 'no'
df['SeniorCitizen']=df['SeniorCitizen'].apply(conv)

# %%
df.head()
# Out:
#    customerID  gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female            no     Yes         No       1           No
# 1  5575-GNVDE    Male            no      No         No      34          Yes
# 2  3668-QPYBK    Male            no      No         No       2          Yes
# 3  7795-CFOCW    Male            no      No         No      45           No
# 4  9237-HQITU  Female            no      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df['SeniorCitizen'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7043 entries, 0 to 7042
# Series name: SeniorCitizen
# Non-Null Count  Dtype
# --------------  -----
# 7043 non-null   object
# dtypes: object(1)
# memory usage: 55.2+ KB

# %%
sns.countplot(x='Churn',data=df)
plt.title('Count of customers by Churn', fontsize=15)
plt.show()

# %%
gb=df.groupby('Churn').agg({"Churn": 'count'})
gb
# Out:
#        Churn
# Churn
# No      5174
# Yes     1869

# %%
plt.figure(figsize=(4,5))
plt.pie(gb['Churn'], labels=gb.index, autopct='%1.2f%%')
plt.title("Percentage of Churned Customers", fontsize=15)
plt.show()

# %% [markdown]
# # 26.5 % of customers were churned out.
# # find the reason behind this and explore it

# %%
plt.figure(figsize=(3,3))
sns.countplot(x='gender',data=df,hue='Churn')
plt.title("Churn by Gender")
plt.show()

# %%
plt.figure(figsize=(3,6))
ax=sns.countplot(x='SeniorCitizen',data=df)
ax.bar_label(ax.containers[0])
plt.title("Churn of custoemrs by SeniorCitizen")
plt.show()

# %%
df = pd.DataFrame(df)


# Calculate the percentage of churn by SeniorCitizen
churn_counts = df.groupby(['SeniorCitizen', 'Churn']).size().unstack(fill_value=0)
churn_percentages = churn_counts.div(churn_counts.sum(axis=1), axis=0) * 100

# Create a stacked bar chart
ax = churn_percentages.plot(kind='bar', stacked=True, figsize=(3, 6))

# Customize the plot
plt.title("Churn by Senior Citizen Status (%)")
plt.xlabel("Senior Citizen (0 = No, 1 = Yes)")
plt.ylabel("Percentage (%)")
plt.legend(title='Churn')
plt.xticks(rotation=0)  # Rotate x-ticks for better readability

# Adding percentage labels on the bars
for i in range(len(churn_percentages)):
    for j in range(len(churn_percentages.columns)):
        percentage = churn_percentages.iloc[i, j]
        ax.text(i, percentage / 2 + (churn_percentages.iloc[i, :j].sum() if j > 0 else 0), 
                f'{percentage:.1f}%', 
                ha='center', va='center', color='white')

plt.show()

# %% [markdown]
# # compartivily seniorcitizen catogory willl be churned out

# %%
plt.figure(figsize=(9,4))
sns.histplot(x='tenure',data=df,bins=72,hue="Churn")
plt.show()

# %% [markdown]
# # people who have useed our serbice long time they are stayed .but people used service 1/2 month they are churned

# %%
plt.figure(figsize=(3,6))
ax=sns.countplot(x='Contract',data=df,hue="Churn")
ax.bar_label(ax.containers[0])
plt.title("Count of customers by Contract")
plt.show()

# %% [markdown]
# # people who have to month contract likly one or two years low churn/// month to month was high churn

# %%
df.columns.values
# Out:
# array(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges',
#        'TotalCharges', 'Churn'], dtype=object)

# %%
df = pd.DataFrame(df)

# List of columns to create count plots for
columns_to_plot = [
    'gender', 'SeniorCitizen', 'Partner', 'Dependents', 
    'PhoneService', 'MultipleLines', 'InternetService', 
    'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 
    'TechSupport', 'StreamingTV', 'StreamingMovies', 
    'Contract', 'PaperlessBilling', 'PaymentMethod', 'Churn'
]

# Number of subplots needed
n_cols = 2  # Adjust number of columns in the subplot grid
n_rows = (len(columns_to_plot) + n_cols - 1) // n_cols  # Calculate number of rows needed

# Set up the figure and axes for subplots
fig, axs = plt.subplots(n_rows, n_cols, figsize=(12, n_rows * 4))
axs = axs.flatten()  # Flatten the array of axes for easy iteration

# Create count plots for each specified column
for i, column in enumerate(columns_to_plot):
    sns.countplot(x=column, data=df, ax=axs[i], hue='Churn')  # You can add hue='Churn' if desired
    axs[i].set_title(f'Count of {column}')
    axs[i].set_ylabel('Count')
    axs[i].set_xlabel(column)
    axs[i].legend(title='Churn')

# Remove any unused subplots
for j in range(i + 1, len(axs)):
    fig.delaxes(axs[j])

# Adjust layout
plt.tight_layout()
plt.show()
# Out:
# C:\Users\salma\AppData\Local\Temp\ipykernel_26224\2021406503.py:26: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs[i].legend(title='Churn')

# %%
plt.figure(figsize=(5,6))
ax=sns.countplot(x='PaymentMethod',data=df,hue="Churn")
ax.bar_label(ax.containers[0])
ax.bar_label(ax.containers[1])
plt.xticks(rotation=45)
plt.title("Count of customers by Contract")
plt.show()
